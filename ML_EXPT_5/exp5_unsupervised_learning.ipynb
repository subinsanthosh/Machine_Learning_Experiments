# %%
import pandas as pd
#Load Data

file_loc = "/content/customers.csv"
wholesale_cust_data = pd.read_csv(file_loc)
wholesale_cust_data.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
row_col = wholesale_cust_data.shape
print("Tota number of rows in the dataset : {}".format(row_col[0]))
print("Total number of columns in the dataset : {}".format(row_col[1]))
# Out:
# Tota number of rows in the dataset : 440
# Total number of columns in the dataset : 8

# %%
wholesale_cust_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel           440 non-null    int64
#  1   Region            440 non-null    int64
#  2   Fresh             440 non-null    int64
#  3   Milk              440 non-null    int64
#  4   Grocery           440 non-null    int64
#  5   Frozen            440 non-null    int64
#  6   Detergents_Paper  440 non-null    int64
#  7   Delicassen        440 non-null    int64
# dtypes: int64(8)
# memory usage: 27.6 KB

# %%
wholesale_cust_data.isna().sum()
# Out:
# Channel             0
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicassen          0
# dtype: int64

# %%
wholesale_cust_data.describe()
# Out:
#           Channel      Region          Fresh          Milk       Grocery  \
# count  440.000000  440.000000     440.000000    440.000000    440.000000
# mean     1.322727    2.543182   12000.297727   5796.265909   7951.277273
# std      0.468052    0.774272   12647.328865   7380.377175   9503.162829
# min      1.000000    1.000000       3.000000     55.000000      3.000000
# 25%      1.000000    2.000000    3127.750000   1533.000000   2153.000000
# 50%      1.000000    3.000000    8504.000000   3627.000000   4755.500000
# 75%      2.000000    3.000000   16933.750000   7190.250000  10655.750000
# max      2.000000    3.000000  112151.000000  73498.000000  92780.000000
#
#              Frozen  Detergents_Paper    Delicassen
# count    440.000000        440.000000    440.000000
# mean    3071.931818       2881.493182   1524.870455
# std     4854.673333       4767.854448   2820.105937
# min       25.000000          3.000000      3.000000
# 25%      742.250000        256.750000    408.250000
# 50%     1526.000000        816.500000    965.500000
# 75%     3554.250000       3922.000000   1820.250000
# max    60869.000000      40827.000000  47943.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# correlation
corr = wholesale_cust_data.corr()
corr.style.background_gradient(cmap='cubehelix')
# Out:
# <style type="text/css">
# #T_a17a0_row0_col0, #T_a17a0_row1_col1, #T_a17a0_row2_col2, #T_a17a0_row3_col3, #T_a17a0_row4_col4, #T_a17a0_row5_col5, #T_a17a0_row6_col6, #T_a17a0_row7_col7 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_a17a0_row0_col1 {
#   background-color: #180f25;
#   color: #f1f1f1;
# }
# #T_a17a0_row0_col2, #T_a17a0_row0_col5, #T_a17a0_row1_col3, #T_a17a0_row1_col7, #T_a17a0_row5_col0, #T_a17a0_row5_col1, #T_a17a0_row5_col4, #T_a17a0_row5_col6 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_a17a0_row0_col3 {
#   background-color: #757b33;
#   color: #f1f1f1;
# }
# #T_a17a0_row0_col4 {
#   background-color: #d383a6;
#   color: #f1f1f1;
# }
# #T_a17a0_row0_col6 {
#   background-color: #d294ce;
#   color: #f1f1f1;
# }
# #T_a17a0_row0_col7 {
#   background-color: #030103;
#   color: #f1f1f1;
# }
# #T_a17a0_row1_col0 {
#   background-color: #15464e;
#   color: #f1f1f1;
# }
# #T_a17a0_row1_col2 {
#   background-color: #16394d;
#   color: #f1f1f1;
# }
# #T_a17a0_row1_col4 {
#   background-color: #100713;
#   color: #f1f1f1;
# }
# #T_a17a0_row1_col5 {
#   background-color: #1a2744;
#   color: #f1f1f1;
# }
# #T_a17a0_row1_col6 {
#   background-color: #1b1a36;
#   color: #f1f1f1;
# }
# #T_a17a0_row2_col0, #T_a17a0_row4_col1 {
#   background-color: #0b040c;
#   color: #f1f1f1;
# }
# #T_a17a0_row2_col1 {
#   background-color: #170e23;
#   color: #f1f1f1;
# }
# #T_a17a0_row2_col3 {
#   background-color: #160d21;
#   color: #f1f1f1;
# }
# #T_a17a0_row2_col4, #T_a17a0_row2_col6, #T_a17a0_row6_col7 {
#   background-color: #0a030a;
#   color: #f1f1f1;
# }
# #T_a17a0_row2_col5 {
#   background-color: #7e7a36;
#   color: #f1f1f1;
# }
# #T_a17a0_row2_col7 {
#   background-color: #16404e;
#   color: #f1f1f1;
# }
# #T_a17a0_row3_col0 {
#   background-color: #bf796d;
#   color: #f1f1f1;
# }
# #T_a17a0_row3_col1 {
#   background-color: #120817;
#   color: #f1f1f1;
# }
# #T_a17a0_row3_col2 {
#   background-color: #154b4e;
#   color: #f1f1f1;
# }
# #T_a17a0_row3_col4 {
#   background-color: #c8afea;
#   color: #000000;
# }
# #T_a17a0_row3_col5 {
#   background-color: #185b48;
#   color: #f1f1f1;
# }
# #T_a17a0_row3_col6 {
#   background-color: #cf9ddb;
#   color: #000000;
# }
# #T_a17a0_row3_col7 {
#   background-color: #447731;
#   color: #f1f1f1;
# }
# #T_a17a0_row4_col0 {
#   background-color: #d392cb;
#   color: #f1f1f1;
# }
# #T_a17a0_row4_col2, #T_a17a0_row4_col5 {
#   background-color: #1a213e;
#   color: #f1f1f1;
# }
# #T_a17a0_row4_col3 {
#   background-color: #cca6e4;
#   color: #000000;
# }
# #T_a17a0_row4_col6 {
#   background-color: #e0f5f0;
#   color: #000000;
# }
# #T_a17a0_row4_col7 {
#   background-color: #192d48;
#   color: #f1f1f1;
# }
# #T_a17a0_row5_col2 {
#   background-color: #727b32;
#   color: #f1f1f1;
# }
# #T_a17a0_row5_col3 {
#   background-color: #19132d;
#   color: #f1f1f1;
# }
# #T_a17a0_row5_col7 {
#   background-color: #3a7533;
#   color: #f1f1f1;
# }
# #T_a17a0_row6_col0 {
#   background-color: #d09cd9;
#   color: #000000;
# }
# #T_a17a0_row6_col1 {
#   background-color: #070206;
#   color: #f1f1f1;
# }
# #T_a17a0_row6_col2 {
#   background-color: #130919;
#   color: #f1f1f1;
# }
# #T_a17a0_row6_col3 {
#   background-color: #d48abb;
#   color: #f1f1f1;
# }
# #T_a17a0_row6_col4 {
#   background-color: #def4ef;
#   color: #000000;
# }
# #T_a17a0_row6_col5 {
#   background-color: #140a1b;
#   color: #f1f1f1;
# }
# #T_a17a0_row7_col0 {
#   background-color: #15424e;
#   color: #f1f1f1;
# }
# #T_a17a0_row7_col1 {
#   background-color: #150b1d;
#   color: #f1f1f1;
# }
# #T_a17a0_row7_col2 {
#   background-color: #357435;
#   color: #f1f1f1;
# }
# #T_a17a0_row7_col3 {
#   background-color: #497830;
#   color: #f1f1f1;
# }
# #T_a17a0_row7_col4 {
#   background-color: #154d4e;
#   color: #f1f1f1;
# }
# #T_a17a0_row7_col5 {
#   background-color: #9c7946;
#   color: #f1f1f1;
# }
# #T_a17a0_row7_col6 {
#   background-color: #18324b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a17a0_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Channel</th>
#       <th class="col_heading level0 col1" >Region</th>
#       <th class="col_heading level0 col2" >Fresh</th>
#       <th class="col_heading level0 col3" >Milk</th>
#       <th class="col_heading level0 col4" >Grocery</th>
#       <th class="col_heading level0 col5" >Frozen</th>
#       <th class="col_heading level0 col6" >Detergents_Paper</th>
#       <th class="col_heading level0 col7" >Delicassen</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a17a0_level0_row0" class="row_heading level0 row0" >Channel</th>
#       <td id="T_a17a0_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a17a0_row0_col1" class="data row0 col1" >0.062028</td>
#       <td id="T_a17a0_row0_col2" class="data row0 col2" >-0.169172</td>
#       <td id="T_a17a0_row0_col3" class="data row0 col3" >0.460720</td>
#       <td id="T_a17a0_row0_col4" class="data row0 col4" >0.608792</td>
#       <td id="T_a17a0_row0_col5" class="data row0 col5" >-0.202046</td>
#       <td id="T_a17a0_row0_col6" class="data row0 col6" >0.636026</td>
#       <td id="T_a17a0_row0_col7" class="data row0 col7" >0.056011</td>
#     </tr>
#     <tr>
#       <th id="T_a17a0_level0_row1" class="row_heading level0 row1" >Region</th>
#       <td id="T_a17a0_row1_col0" class="data row1 col0" >0.062028</td>
#       <td id="T_a17a0_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_a17a0_row1_col2" class="data row1 col2" >0.055287</td>
#       <td id="T_a17a0_row1_col3" class="data row1 col3" >0.032288</td>
#       <td id="T_a17a0_row1_col4" class="data row1 col4" >0.007696</td>
#       <td id="T_a17a0_row1_col5" class="data row1 col5" >-0.021044</td>
#       <td id="T_a17a0_row1_col6" class="data row1 col6" >-0.001483</td>
#       <td id="T_a17a0_row1_col7" class="data row1 col7" >0.045212</td>
#     </tr>
#     <tr>
#       <th id="T_a17a0_level0_row2" class="row_heading level0 row2" >Fresh</th>
#       <td id="T_a17a0_row2_col0" class="data row2 col0" >-0.169172</td>
#       <td id="T_a17a0_row2_col1" class="data row2 col1" >0.055287</td>
#       <td id="T_a17a0_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_a17a0_row2_col3" class="data row2 col3" >0.100510</td>
#       <td id="T_a17a0_row2_col4" class="data row2 col4" >-0.011854</td>
#       <td id="T_a17a0_row2_col5" class="data row2 col5" >0.345881</td>
#       <td id="T_a17a0_row2_col6" class="data row2 col6" >-0.101953</td>
#       <td id="T_a17a0_row2_col7" class="data row2 col7" >0.244690</td>
#     </tr>
#     <tr>
#       <th id="T_a17a0_level0_row3" class="row_heading level0 row3" >Milk</th>
#       <td id="T_a17a0_row3_col0" class="data row3 col0" >0.460720</td>
#       <td id="T_a17a0_row3_col1" class="data row3 col1" >0.032288</td>
#       <td id="T_a17a0_row3_col2" class="data row3 col2" >0.100510</td>
#       <td id="T_a17a0_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_a17a0_row3_col4" class="data row3 col4" >0.728335</td>
#       <td id="T_a17a0_row3_col5" class="data row3 col5" >0.123994</td>
#       <td id="T_a17a0_row3_col6" class="data row3 col6" >0.661816</td>
#       <td id="T_a17a0_row3_col7" class="data row3 col7" >0.406368</td>
#     </tr>
#     <tr>
#       <th id="T_a17a0_level0_row4" class="row_heading level0 row4" >Grocery</th>
#       <td id="T_a17a0_row4_col0" class="data row4 col0" >0.608792</td>
#       <td id="T_a17a0_row4_col1" class="data row4 col1" >0.007696</td>
#       <td id="T_a17a0_row4_col2" class="data row4 col2" >-0.011854</td>
#       <td id="T_a17a0_row4_col3" class="data row4 col3" >0.728335</td>
#       <td id="T_a17a0_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_a17a0_row4_col5" class="data row4 col5" >-0.040193</td>
#       <td id="T_a17a0_row4_col6" class="data row4 col6" >0.924641</td>
#       <td id="T_a17a0_row4_col7" class="data row4 col7" >0.205497</td>
#     </tr>
#     <tr>
#       <th id="T_a17a0_level0_row5" class="row_heading level0 row5" >Frozen</th>
#       <td id="T_a17a0_row5_col0" class="data row5 col0" >-0.202046</td>
#       <td id="T_a17a0_row5_col1" class="data row5 col1" >-0.021044</td>
#       <td id="T_a17a0_row5_col2" class="data row5 col2" >0.345881</td>
#       <td id="T_a17a0_row5_col3" class="data row5 col3" >0.123994</td>
#       <td id="T_a17a0_row5_col4" class="data row5 col4" >-0.040193</td>
#       <td

# %%
wholesale_cust_data["Channel"] = wholesale_cust_data["Channel"].replace(1,"Hotel")
wholesale_cust_data["Channel"] = wholesale_cust_data["Channel"].replace(2,"Retail")

# Replace values
wholesale_cust_data["Region"] = wholesale_cust_data["Region"].replace(1,"Lisbon")
wholesale_cust_data["Region"] = wholesale_cust_data["Region"].replace(2,"Oporto")
wholesale_cust_data["Region"] = wholesale_cust_data["Region"].replace(3,"Other")

import matplotlib.pyplot as plt
import seaborn as sns 
colmns = ['Channel','Region']
for col in colmns:
    sns.set_style("whitegrid")
    plt.figure(figsize = (8,5))
    sns.countplot(x=wholesale_cust_data[col], data=wholesale_cust_data) 
    plt.show()

# %%
sns.set_style('whitegrid')
sns.countplot(x="Channel",hue='Region',data=wholesale_cust_data)

# %%
cols = wholesale_cust_data.select_dtypes(exclude ='object').columns

for i in cols:
    sns.set_theme(style="whitegrid")
    plt.figure(figsize=(10,3))
    ax = sns.boxplot(x=wholesale_cust_data[i])
